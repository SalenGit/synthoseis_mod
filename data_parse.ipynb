# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
semi = np.load('../output/test4/seismic__2024.84864459_5/seismicCubes_RFC_fullstack')
falt = np.load('../output/test4/seismic__2024.84864459_5/fault_segments_')

# %%
semi.shape, falt.shape
# Out:
# ((300, 300, 1259), (300, 300, 1260))

# %%
index = 40
plt.figure(figsize=(10,5))
plt.subplot(211)
plt.imshow(semi[:, index])
plt.subplot(212)
plt.imshow(falt.astype(bool)[:, index])

# %%
plt.imshow(falt[:, 10])

# %%
np.unique(falt)
# Out:
# array([0., 1.])

# %%
plt.imshow(semi[210])
