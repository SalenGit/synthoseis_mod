# %%
import main as mn
from joblib.parallel import Parallel,delayed
from tqdm import tqdm

# %%
Parallel(n_jobs=1)(delayed(mn.build_model)(user_json='./config/example.json',run_id=i) for i in tqdm(range(1000)))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Coherent frowns will be inserted
# Salt will be NOT be inserted.
#
# Model folder: /home/salen/think/darkside/synthoseis_mod/output/test4/seismic__2024.85571817
# Creating directory: ./output/test4
# Creating directory: /home/salen/think/darkside/synthoseis_mod/output/test4/seismic__2024.85571817
# Creating directory: /home/salen/think/darkside/synthoseis_mod/output/temp_folder__2024.85571817
#
# Keyfile created at /home/salen/think/darkside/synthoseis_mod/output/test4/seismic__2024.85571817/seismicCube_2024.85571817.key
# self.cfg.num_lyr_lut =  25000
# onlap_layer_list =  [ 66 161]
# Number of onlapping flags: 2
#  ... horizon number for first onlap episode = 66
#  ... number of channelFlags: 0
#  ... horizon number for first channel episode: 0
# 	Indices for shallowest point in cube: 0, 297
# Building random depth map at base of model
# azi, dip, dipping_plane min/mean/max = 349.28568758720706, 0.15537190919609922, 0.00, 0.67, 1.34
# ...

# %%
raise ValueError
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 raise ValueError
#
# ValueError:

# %%
# %%time

mn.build_model(user_json='./config/example.json',run_id=3)
# Out:
# No coherent noise will be inserted
# Salt will be NOT be inserted.
#
# Model folder: /media/data/think_darkside/synthoseis/output/test4/seismic__2024.84826585_3
# Creating directory: /media/data/think_darkside/synthoseis/output/test4/seismic__2024.84826585_3
# Creating directory: /media/data/think_darkside/synthoseis/output/temp_folder__2024.84826585_3
#
# Keyfile created at /media/data/think_darkside/synthoseis/output/test4/seismic__2024.84826585_3/seismicCube_2024.84826585.key
# self.cfg.num_lyr_lut =  25000
# onlap_layer_list =  [ 67  83 195]
# Number of onlapping flags: 3
#  ... horizon number for first onlap episode = 67
#  ... number of channelFlags: 0
#  ... horizon number for first channel episode: 0
# 	Indices for shallowest point in cube: 299, 0
# Building random depth map at base of model
# azi, dip, dipping_plane min/mean/max = 140.117378633493, 0.19071994554615235, 0.00, 0.99, 1.98
# current_depth_map min/mean/max = 12455.63, 12897.08, 13354.57
# ...
